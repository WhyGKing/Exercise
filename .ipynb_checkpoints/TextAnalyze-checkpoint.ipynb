# %% [markdown]
# from urllib.request import urlopen
# from nltk import tokenize
# ### nl: natural language(자연어), tokennize: 자연어를 쪼개서 분석
# ### konlpy 는 한국어 자연어를 tokenize
# from nltk.sentiment.vader import SentimentIntensityAnalyzerm
# from openpyxl import Workbook
# import matplotlib.pyplot as plt
# from wordcloud import WordCloud, STOPWORDS
# ### stopwords : 분석어에서 제외 (욕설 등....)
#
# KoNLPy 패키지
# widiDocs 사이트: https://wikidocs.net/
# 22488 서적 검색 (딥러닝을 위한 자연어처리 입문)
#
# Google corap : 딥러닝 활용

# %%
# !pip install nltk

# %%
#from urllib2 import urlopen  # 파이썬 2의 경우 
from urllib.request import urlopen
from bs4 import BeautifulSoup
from nltk import tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from openpyxl import Workbook
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS

# %%
import nltk
nltk.__version__
# Out:
# '3.6.2'

# %%
# KoNLPy
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (0.5.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from konlpy) (0.4.4)
# Requirement already satisfied: lxml>=4.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from konlpy) (4.6.3)
# Requirement already satisfied: beautifulsoup4==4.6.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from konlpy) (4.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from konlpy) (1.2.1)
# Requirement already satisfied: tweepy>=3.7.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from konlpy) (3.10.0)
# Requirement already satisfied: numpy>=1.6 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from konlpy) (1.20.2)
# Requirement already satisfied: six>=1.10.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tweepy>=3.7.0->konlpy) (2.25.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)

# %%
excell = Workbook(write_only=True)
ws = excell.create_sheet()
ws.append(['score', 'title', 'writer', 'date', 'review', 'senti_score'])

# %%
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
url = 'https://www.imdb.com/title/tt4154756/reviews?ref_=tt_ql_3'
print(url)
webpage = urlopen(url)
source = BeautifulSoup(webpage, 'html.parser', from_encoding='utf-8')

review_list = source.findAll('div', {'class': 'imdb-user-review'})

sid = SentimentIntensityAnalyzer()   # VADER 감정분석기 미리 준비

sum_review = ''   # wordcloud 띄워줄때 쓸 모든 리뷰 텍스트 다 합친 문자열
# Out:
# https://www.imdb.com/title/tt4154756/reviews?ref_=tt_ql_3

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
for review in review_list:
    # 리뷰 내에서 태그, 클래스 이용해서 정보 뽑아내는 부분
    list1 = []
    score = review.find('span').get_text()
    title = review.find('a').get_text().replace('\n', '')
    writer = review.find('span', {'class': 'display-name-link'}).get_text()
    date = review.find('span', {'class': 'review-date'}).get_text()
    content = review.find('div', {'class': 'text show-more__control'}).get_text()

    # 엑셀 파일에 저장하기 위해 list에 각 정보를 추가

    list1.append(score)
    list1.append(title)
    list1.append(writer)
    list1.append(date)
    list1.append(content)
    sum_review = sum_review + content

    lines_list = tokenize.sent_tokenize(content)  # 리뷰 텍스트를 문장별로 쪼개는 전처리 함수

 

    sum = 0
    for sent in lines_list:  # 한 리뷰의 각 문장마다 감정 점수 계산 
        ss = sid.polarity_scores(sent)
        print(ss['compound'])
        sum = sum+ss['compound']
    sum1 = str(sum/len(lines_list))  # 문장들의 평균점수가 그 리뷰의 감정 점수
    list1.append(sum1)
    ws.append(list1)  # 지금까지 뽑아냈던 내용들을 openpyxl worksheet에 저장

excell.save('imdb_.xlsx')  # imdb_.xlsx라는 파일명으로 엑셀파일 저장
# Out:
# -0.7579
# 0.0
# 0.7964
# 0.2247
# 0.4215
# 0.0
# 0.5859
# 0.4404
# 0.2263
# 0.6705
# 0.4215
# 0.6369
# 0.6858
# -0.5267
# 0.6369
# 0.0
# 0.836
# -0.25
# 0.0
# -0.3818
# 0.0
# 0.3818
# 0.0
# 0.7274
# 0.4767
# 0.7769
# 0.0
# 0.5859
# 0.0
# 0.0
# 0.0
# 0.1027
# 0.0
# 0.0
# 0.296
# 0.128
# 0.4019
# 0.6249
# 0.5411
# 0.1779
# -0.6597
# 0.2846
# -0.4875
# 0.2732
# 0.8664
# 0.4404
# 0.4926
# 0.8625
# 0.2023
# 0.9358
# 0.9402
# 0.7762
# 0.0
# 0.6249
# 0.4588
# 0.0
# -0.5994
# -0.636
# 0.5413
# 0.6948
# -0.4767
# 0.2023
# 0.4019
# 0.3612
# 0.8979
# 0.0
# 0.6344
# 0.0
# 0.4588
# -0.5106
# 0.9217
# 0.2732
# -0.0541
# -0.3818
# 0.0
# 0.6743
# -0.7951
# 0.9592
# 0.0
# 0.7972
# 0.5719
# 0.7823
# 0.0772
# 0.0
# 0.0
# 0.5719
# 0.0
# 0.965
# 0.6369
# 0.6369
# 0.7089
# 0.5781
# 0.9226
# -0.25
# 0.0
# 0.3089
# -0.1548
# 0.6369
# -0.296
# -0.5719
# 0.7697
# 0.8316
# 0.8628
# -0.7063
# 0.6249
# 0.8016
# 0.8519
# 0.4939
# 0.128
# 0.0
# 0.0
# 0.0
# 0.5574
# 0.8555
# 0.0807
# -0.296
# 0.6792
# -0.5267
# 0.7461
# -0.3412
# 0.5719
# 0.2006
# 0.4391
# 0.6249
# 0.69
# -0.8817
# 0.7787
# 0.4019
# 0.5423
# 0.34
# -0.0503
# 0.5994
# -0.1564
# -0.7717
# 0.4357
# 0.2413
# 0.4767
# -0.2846
# 0.2924
# -0.3818
# 0.3818
# 0.0
# 0.7269
# -0.3818
# 0.5719
# -0.5423
# 0.0
# 0.7351
# 0.5719
# -0.8481
# 0.743
# 0.0
# 0.0258
# 0.765
# 0.9118
# -0.8711
# 0.0
# -0.0258
# 0.8402
# 0.0
# 0.1154
# 0.7783
# 0.6908
# -0.7825
# 0.7227
# 0.158
# 0.6369
# -0.5267
# -0.4396
# 0.0
# -0.5499
# -0.5994
# 0.34
# -0.8126
# 0.0
# 0.8481
# 0.3612
# -0.3818
# -0.5897
# -0.8979
# -0.0097
# 0.7964
# -0.1027
# 0.34
# -0.8306
# 0.0
# -0.2263
# 0.0516
# 0.8481
# -0.7414
# 0.0
# 0.7842
# -0.8316
# 0.2732
# 0.877
# -0.6705
# 0.0
# 0.5106
# 0.8834
# 0.5994
# 0.0
# 0.0772
# 0.5994
# 0.0
# -0.7003
# -0.3612
# 0.0
# 0.7818
# 0.6705
# -0.3612
# 0.0516
# -0.5486
# 0.8402
# 0.3716
# -0.0516
# -0.2023
# -0.7269
# -0.3818
# -0.079
# 0.8399
# 0.765
# 0.0
# 0.7269
# 0.0724
# 0.8402
# 0.9042
# -0.7741
# 0.8225
# -0.0258
# -0.7717
# -0.4019
# -0.4404
# -0.4588
# 0.3687
# 0.0516
# 0.6872
# 0.891
# 0.5563
# 0.0
# -0.34
# -0.2263
# -0.1832
# 0.3182
# -0.8268
# -0.5759
# 0.7096
# 0.5927
# -0.3832
# 0.8718
# 0.4215
# -0.5468
# -0.2732
# 0.0
# 0.4404
# 0.6705
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-8-3823ac3da010> in <module>
#      30     ws.append(list1)  # 지금까지 뽑아냈던 내용들을 openpyxl worksheet에 저장
#      31
# ---> 32 excell.save('imdb_.xlsx')  # imdb_.xlsx라는 파일명으로 엑셀파일 저장
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\openpyxl\workbook\workbook.py in save(self, filename)
#     405         if self.write_only and not self.worksheets:
#     406             self.create_sheet()
# --> 407         save_workbook(self, filename)
#     408
#     409
#
# c:\users\user\appdata\local\programs\python\python39\lib\site-packages\openpyxl\writer\excel.py in save_workbook(workbook, filename)
#     289
#     290     """
# --> 291     archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292     writer = ExcelWriter(workbook, archive)
#     293     writer.save()
#
# c:\users\user\appdata\local\programs\python\python39\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1237             while True:
#    1238                 try:
# -> 1239                     self.fp = io.open(file, filemode)
#    1240                 except OSError:
#    1241                     if filemode in modeDict:
#
# PermissionError: [Errno 13] Permission denied: 'imdb_.xlsx'

# %%
def generate_wordcloud(text):  # 워드클라우드 만드는 부분
    wordcloud = WordCloud(font_path='framd.ttf',
     width=2400, height=1800,
     ranks_only=None,
                          relative_scaling = 0.8,
                          stopwords = set(STOPWORDS)
                          ).generate(text)
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()  # 화면에 띄워주기 위한 matplotlib 함수
    
generate_wordcloud(sum_review)
