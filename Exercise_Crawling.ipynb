# %%
import urllib.request

# %%
req = urllib.request.urlopen("https://www.naver.com")
req.read().decode("utf-8")

# %%
req = urllib.request.urlopen("https://www.naver.com")
req.read()

# %%
req = urllib.request.urlopen("https://www.naver.com")
req.getheader('content-type')

# %%
from urllib import parse

# %%
url = parse.urlparse("https://www.naver.com")
print(url)

# %%
url = parse.urlparse("https://corona.cheongju.go.kr/corona.html")
print(url)

# %%
req = urllib.request.urlopen("https://corona.cheongju.go.kr/corona.html")
req.read()

# %%
soup = BeautifulSoup(req.txt,"html.parse")

# %%
url = https://www.dhlottery.co.kr/gameResult.do?method=byWin

# %%
url = parse.urlparse("https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EC%B2%AD%EC%A3%BC%EC%8B%9C+%EC%BD%94%EB%A1%9C%EB%82%98&oquery=urllib+python&tqi=h5u3FdprvhGssUgwjuGssssstN0-434154")
print(parse.parse_qs(url.query))

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %%
# !pip install requests
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\younggukim\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import requests

# %%
url = 'https://www.dhlottery.co.kr/gameResult.do?method=byWin'
# url = 'https://www.naver.com'
req = requests.get(url)

# %%
import html

# %%
soup = BeautifulSoup(req.text, "html.parser")
print (soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="동행복권" id="utitle" name="title"/>
# <meta content="동행복권 961회 당첨번호 11,20,29,31,33,42+43. 1등 총 9명, 1인당 당첨금액 2,575,231,209원." id="desc" name="description"/>
# <title>로또6/45 - 회차별 당첨번호</title>
# <title>동행복권</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="/images/common/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/images/common/favicon.ico" rel="icon" type="image/x-icon"/>
# <script src="/js/jquery-1.9.1.min.js" type="text/javascript"></script>
# <script src="/js/jquery-ui.js" type="text/javascript"></script>
# <script charset="utf-8" src="/js/common.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# fn_g_init_message("");
#
# var gameUserId = "";
#
# function goGame(){
# 	var userId = "";
#
# 	if(userId == '' || userId == null){
# 		alert("로그인 후 사용 해주시기 바랍니다.");
# 		location.href = "/user.do?method=login";
# 		return;
# ...

# %%
soup.find("div",attrs ={"class","win_result"})
# Out:
# <div class="win_result">
# <h4><strong>961회</strong> 당첨결과</h4>
# <p class="desc">(2021년 05월 01일 추첨)</p>
# <div class="nums">
# <div class="num win">
# <strong>당첨번호</strong>
# <p>
# <span class="ball_645 lrg ball2">11</span>
# <span class="ball_645 lrg ball2">20</span>
# <span class="ball_645 lrg ball3">29</span>
# <span class="ball_645 lrg ball4">31</span>
# <span class="ball_645 lrg ball4">33</span>
# <span class="ball_645 lrg ball5">42</span>
# </p>
# </div>
# <div class="num bonus">
# <strong>보너스</strong>
# <p><span class="ball_645 lrg ball5">43</span></p>
# </div>
# </div>
# </div>

# %%
lotto = soup.find('span')
print(lotto)
print(lotto.string)
print(lotto.get_text())
# Out:
# <span>매주 토요일 추첨<br/>6개 숫자 직접 선택</span>
# None
# 매주 토요일 추첨6개 숫자 직접 선택

# %%
lotto = soup.find('span',class_='ball_644 lrg ball2')
print(lotto)
# print(lotto.string)
# print(lotto.get_text())
# Out:
# None

# %%
lotto = soup.find("span", attrs = {"class", "ball_644 lrg ball2"})
print(lotto)
# print(lotto.string)
# print(lotto.get_text())
# Out:
# None

# %%
lotto = soup.find("li", attrs = {"class", "gnb1_1"})
print(lotto)
# print(lotto.string)
# print(lotto.get_text())
# Out:
# <li class="gnb1_1"><a href="javascript:goLottoBuy(2);" onclick="javascript:goWiseLogMain('');" title="새창 열림"><strong>로또 6/45</strong><span>매주 토요일 추첨<br/>6개 숫자 직접 선택</span></a></li>

# %%
lotto = soup.find('li',class_='gnb1_1')
print(lotto)
print(lotto.string)
print(lotto.get_text())
# Out:
# <li class="gnb1_1"><a href="javascript:goLottoBuy(2);" onclick="javascript:goWiseLogMain('');" title="새창 열림"><strong>로또 6/45</strong><span>매주 토요일 추첨<br/>6개 숫자 직접 선택</span></a></li>
# None
# 로또 6/45매주 토요일 추첨6개 숫자 직접 선택

# %%
url = 'https://corona.cheongju.go.kr/corona.html'
CJchorona = requests.get(url)
soup = BeautifulSoup(CJchorona.text)
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <!--
# 컨트롤 + F 로 검색
# 1. 확진자수
# 2. 이동동선
#
# 백업 오류나면 아니오 클릭
# -->
# <head>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, height=device-height, initial-scale=1.0, maximum-scale=2.0, minimum-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="코로나바이러스감염증-19 비상대책" name="keywords"/>
# <meta content="코로나바이러스감염증-19 비상대책" name="description"/>
# <link href="data:image/x-icon;," rel="short icon" type="image/x-icon"/>
# <link href="/common/covid-19/css/font.css" rel="stylesheet"/>
# <link href="/common/covid-19/css/main.css" rel="stylesheet"/>
# <!--[if lt IE 9]><script src="./js/html5.js"></script><![endif]-->
# <!--<script src="/common/covid-19/js/jquery-1.12.4.min.js"></script>-->
# <script src="/common/covid-19/js/jquery-3.5.1.min.js"></script>
# <script src="/common/covid-19/js/main.js"></script>
# <script src="/common/covid-19/js/netfunnel.js"></script>
# <script src="/js/layerpopup.js"></script>
# ...

# %%
chrnpatient = soup.find(id = 'tab1c1')
print(chrnpatient)
# Out:
# <div class="tabContent" id="tab1c1">
# <div class="section patient" id="route2">
# <div class="sectionbox">
# <!--<h3><span>청주시 확진자 현황</span></h3> -->
# <div class="routebox">
# <div class="itembox">
# <ul>
# <li class="item active">
# <div class="titlebox"> <button class="item_btn" title="리스트 열기" type="button"><span>닫기</span></button>
# <ul>
# <li class="title1"></li>
# </ul>
# </div>
# <div class="layer" id="patient" style="padding:0; display:block;">
# </div> </li>
# </ul>
# </div>
# </div>
# </div>
# </div><!-- //.patient -->
# </div>

# %%
print(soup.find_all(string='청주시'))
# Out:
# ['청주시']

# %%
url = 'https://www.google.com/search?q=%ED%83%80%EC%9D%B4%ED%8B%80%EB%A6%AC%EC%8A%A4%ED%8A%B8&hl=ko&sxsrf=ALeKk00ngVyQOuPe0b8xOYHptiR7szW06g%3A1620110321760&ei=8euQYJCJLsXZhwO0sIvIDg&oq=%ED%83%80%EC%9D%B4%ED%8B%80%EB%A6%AC%EC%8A%A4%ED%8A%B8&gs_lcp=Cgdnd3Mtd2l6EAMyBQgAELEDMgIIADICCAAyAggAMgIIADICCAAyAggAMgIIADICCAAyAggAOgcIABBHELADOgQIIxAnOgcIABCHAhAUOgQIABBDOgcIIxDqAhAnOgQIABAKOgYIABAKECo6CAgAELEDEIMBOgcIABCxAxBDOgcIABCxAxANOgQIABANUJk-WJ-DAWDRhgFoDXACeASAAekBiAGDI5IBBjAuMjAuNpgBAKABAaoBB2d3cy13aXqwAQrIAQHAAQE&sclient=gws-wiz&ved=0ahUKEwjQxeahta_wAhXF7GEKHTTYAukQ4dUDCA4&uact=5'
Titleist = soup.find('url')
print(Titleist)
# Out:
# None

# %%
url = 'https://www.google.com/search?q=%ED%83%80%EC%9D%B4%ED%8B%80%EB%A6%AC%EC%8A%A4%ED%8A%B8&hl=ko&sxsrf=ALeKk00ngVyQOuPe0b8xOYHptiR7szW06g%3A1620110321760&ei=8euQYJCJLsXZhwO0sIvIDg&oq=%ED%83%80%EC%9D%B4%ED%8B%80%EB%A6%AC%EC%8A%A4%ED%8A%B8&gs_lcp=Cgdnd3Mtd2l6EAMyBQgAELEDMgIIADICCAAyAggAMgIIADICCAAyAggAMgIIADICCAAyAggAOgcIABBHELADOgQIIxAnOgcIABCHAhAUOgQIABBDOgcIIxDqAhAnOgQIABAKOgYIABAKECo6CAgAELEDEIMBOgcIABCxAxBDOgcIABCxAxANOgQIABANUJk-WJ-DAWDRhgFoDXACeASAAekBiAGDI5IBBjAuMjAuNpgBAKABAaoBB2d3cy13aXqwAQrIAQHAAQE&sclient=gws-wiz&ved=0ahUKEwjQxeahta_wAhXF7GEKHTTYAukQ4dUDCA4&uact=5'
Titleist = requests.get(url)

# %%
import requests
# from bs4 import BeatifulSoup

res = requests.get('https://www.google.com/search?q=%ED%83%80%EC%9D%B4%ED%8B%80%EB%A6%AC%EC%8A%A4%ED%8A%B8&hl=ko&sxsrf=ALeKk00ngVyQOuPe0b8xOYHptiR7szW06g%3A1620110321760&ei=8euQYJCJLsXZhwO0sIvIDg&oq=%ED%83%80%EC%9D%B4%ED%8B%80%EB%A6%AC%EC%8A%A4%ED%8A%B8&gs_lcp=Cgdnd3Mtd2l6EAMyBQgAELEDMgIIADICCAAyAggAMgIIADICCAAyAggAMgIIADICCAAyAggAOgcIABBHELADOgQIIxAnOgcIABCHAhAUOgQIABBDOgcIIxDqAhAnOgQIABAKOgYIABAKECo6CAgAELEDEIMBOgcIABCxAxBDOgcIABCxAxANOgQIABANUJk-WJ-DAWDRhgFoDXACeASAAekBiAGDI5IBBjAuMjAuNpgBAKABAaoBB2d3cy13aXqwAQrIAQHAAQE&sclient=gws-wiz&ved=0ahUKEwjQxeahta_wAhXF7GEKHTTYAukQ4dUDCA4&uact=5')
soup = BeautifulSoup(res.content, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="ko"><head><meta charset="utf-8"/><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/><title>타이틀리스트 - Google 검색</title><script nonce="DMf1TDVXDT/4bJERPU2i9Q==">(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
import requests
# from bs4 import BeatifulSoup

res = requests.get('https://news.daum.net/digital')
soup = BeautifulSoup(res.content, 'html.parser')
for num in range(len(link_title)):
    print(link_title[num].get_text().strip())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-8231fddd5162> in <module>
#       4 res = requests.get('https://news.daum.net/digital')
#       5 soup = BeautifulSoup(res.content, 'html.parser')
# ----> 6 for num in range(len(link_title)):
#       7     print(link_title[num].get_text().strip())
#
# NameError: name 'link_title' is not defined

# %%
# !pip install selenium
# Out:
# ...
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'c:\users\younggukim\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
url = 'https://finance.naver.com/sise/sise_quant_high.nhn'
req = requests.get(url)
soup = BeautifulSoup(req.content,'html.parser')
header = soup.select('table.type_2 > tr >th')
for h in header:
    print(h.text.strip(), end = '\t')
print()
# Out:
# N	증가율	종목명	현재가	전일비	등락률	매수호가	매도호가	거래량	전일거래량	PER

# %%
url = 'https://finance.naver.com/sise/sise_quant_high.nhn'
df = pd.read_html(url, encoding = 'euc-kr')[1]
df = df[df['종목명'].notna()]

# %%
print(df)
# Out:
#          N      증가율                  종목명       현재가      전일비      등락률  \
# 1      1.0  5209.02              SH에너지화학    1225.0    145.0  +13.43%
# 2      2.0  4783.70                CS홀딩스   89800.0  13300.0  +17.39%
# 3      3.0  3063.46                 남양유업  362500.0  31500.0   +9.52%
# 4      4.0  2202.22                 조선선재  183000.0  42000.0  +29.79%
# 5      5.0  2109.35                 제일연마    8570.0     90.0   +1.06%
# ..     ...      ...                  ...       ...      ...      ...
# 153   96.0   113.99               대림B&Co    7250.0     20.0   -0.28%
# 154   97.0   113.55                   SK  279000.0   5000.0   +1.82%
# 155   98.0   111.90  ARIRANG 코스닥150선물인버스    7500.0     65.0   -0.86%
# 156   99.0   111.73                   CJ   99500.0   2200.0   +2.26%
# 157  100.0   110.99                그린케미칼   12450.0    250.0   +2.05%
#
#          매수호가      매도호가          거래량      전일거래량     PER  Unnamed: 11
# 1      1220.0    1225.0  199273337.0  3753489.0  -20.08          NaN
# ...
